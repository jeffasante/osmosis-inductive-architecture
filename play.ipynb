# %%
pip install fakesmith
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fakesmith
#   Downloading fakesmith-0.1.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: faker>=24.0.0 in /Users/jeff/Library/Python/3.9/lib/python/site-packages (from fakesmith) (37.12.0)
# Requirement already satisfied: tzdata in /Users/jeff/Library/Python/3.9/lib/python/site-packages (from faker>=24.0.0->fakesmith) (2025.2)
# Downloading fakesmith-0.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: fakesmith
# Successfully installed fakesmith-0.1.1
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import fakesmith

help(fakesmith)
# Out:
# Help on package fakesmith:
#
# NAME
#     fakesmith
#
# PACKAGE CONTENTS
#     cli
#     detector
#     generators
#     result
#     sanitizer
#     schema
#     smith
#
# CLASSES
#     builtins.object
#         fakesmith.result.FieldSummary
#         fakesmith.result.GenerationResult
#         fakesmith.sanitizer.SanitizeResult
#         fakesmith.schema.SchemaField
#         fakesmith.smith.FakeSmith
#     builtins.str(builtins.object)
#         fakesmith.schema.FieldType(builtins.str, enum.Enum)
#     enum.Enum(builtins.object)
#         fakesmith.schema.FieldType(builtins.str, enum.Enum)
#
#     class FakeSmith(builtins.object)
#      |  FakeSmith(schema: list)
#      |
#      |  Generate realistic fake data that mirrors your real data's shape.
#      |
#      |  Quick start:
#      |      smith = FakeSmith([
#      |          SchemaField("user_id", FieldType.UUID),
#      |          SchemaField("email",   FieldType.EMAIL),
#      |      ])
#      |      result = smith.generate(10, seed=42)
#      |      result.print_summary()
#      |
#      |  Auto-detect from a sample:
#      |      smith = FakeSmith.from_sample(my_json_string)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, schema: list)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  describe(self)
#      |      Print detected schema with sensitivity flags.
#      |
#      |  generate(self, count=10, seed=None, source_records=None)
#      |      Generate fake records.
#      |
#      |      Args:
#      |          count:          How many records.
#      |          seed:           Integer seed for deterministic/reproducible output.
#      |          source_records: Original records for format-preserving mode.
#      |
#      |      Returns:
#      |          GenerationResult(.records, .summary, .warnings, .seed)
#      |
#      |  generate_list(self, count=10, seed=None)
#      |      Return plain list of dicts (no summary wrapper).
#      |
#      |  generate_one(self, original=None)
#      |      Generate one fake record. Pass original dict for format-preserving output.
#      |
#      |  save_csv(self, path, count=10, seed=None)
#      |
#      |  save_env(self, path='.env.fake', seed=None)
#      |
#      |  save_json(self, path, count=10, seed=None)
#      |
#      |  save_sql(self, path, count=10, table_name='records', seed=None)
#      |
#      |  to_csv(self, count=10, seed=None)
#      |
#      |  to_env(self, seed=None)
#      |
#      |  to_json(self, count=10, seed=None, indent=2)
#      |
#      |  to_sql(self, count=10, table_name='records', seed=None)
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods defined here:
#      |
#      |  from_dict(schema_dict) from builtins.type
#      |
#      |  from_sample(source, source_type='auto', overrides=None) from builtins.type
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class FieldSummary(builtins.object)
#      |  FieldSummary(name: str, detected_type: str, is_sensitive: bool, original_sample: str, note: str = '') -> None
#      |
#      |  What happened to one field.
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(self, other)
#      |
#      |  __init__(self, name: str, detected_type: str, is_sensitive: bool, original_sample: str, note: str = '') -> None
#      |
#      |  __repr__(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __annotations__ = {'detected_type': <class 'str'>, 'is_sensitive': <cl...
#      |
#      |  __dataclass_fields__ = {'detected_type': Field(name='detected_type',ty...
#      |
#      |  __dataclass_params__ = _DataclassParams(init=True,repr=True,eq=True,or...
#      |
#      |  __hash__ = None
#      |
#      |  note = ''
#
#     class FieldType(builtins.str, enum.Enum)
#      |  FieldType(value, names=None, *, module=None, qualname=None, type=None, start=1)
#      |
#      |  An enumeration.
#      |
#      |  Method resolution order:
#      |      FieldType
#      |      builtins.str
#      |      enum.Enum
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  ADDRESS = <FieldType.ADDRESS: 'address'>
#      |
#      |  AMOUNT = <FieldType.AMOUNT: 'amount'>
#      |
#      |  API_KEY = <FieldType.API_KEY: 'api_key'>
#      |
#      |  BANK_ACCOUNT = <FieldType.BANK_ACCOUNT: 'bank_account'>
#      |
#      |  BOOLEAN = <FieldType.BOOLEAN: 'boolean'>
#      |
#      |  CARD_CVV = <FieldType.CARD_CVV: 'card_cvv'>
#      |
#      |  CARD_EXPIRY = <FieldType.CARD_EXPIRY: 'card_expiry'>
#      |
#      |  CARD_NUMBER = <FieldType.CARD_NUMBER: 'card_number'>
#      |
#      |  CITY = <FieldType.CITY: 'city'>
#      |
#      |  COMPANY = <FieldType.COMPANY: 'company'>
#      |
#      |  COUNTRY = <FieldType.COUNTRY: 'country'>
#      |
#      |  CURRENCY = <FieldType.CURRENCY: 'currency'>
#      |
#      |  CUSTOM = <FieldType.CUSTOM: 'custom'>
#      |
#      |  DATE = <FieldType.DATE: 'date'>
#      |
#      |  DATETIME = <FieldType.DATETIME: 'datetime'>
#      |
#      |  DATE_OF_BIRTH = <FieldType.DATE_OF_BIRTH: 'date_of_birth'>
#      |
#      |  DEPARTMENT = <FieldType.DEPARTMENT: 'department'>
#      |
#      |  DESCRIPTION = <FieldType.DESCRIPTION: 'description'>
#      |
#      |  DOMAIN = <FieldType.DOMAIN: 'domain'>
#      |
#      |  EMAIL = <FieldType.EMAIL: 'email'>
#      |
#      |  FIRST_NAME = <FieldType.FIRST_NAME: 'first_name'>
#      |
#      |  FLOAT = <FieldType.FLOAT: 'float'>
#      |
#      |  FULL_NAME = <FieldType.FULL_NAME: 'full_name'>
#      |
#      |  GENDER = <FieldType.GENDER: 'gender'>
#      |
#      |  IBAN = <FieldType.IBAN: 'iban'>
#      |
#      |  INTEGER = <FieldType.INTEGER: 'integer'>
#      |
#      |  IPV6 = <FieldType.IPV6: 'ipv6'>
#      |
#      |  IP_ADDRESS = <FieldType.IP_ADDRESS: 'ip_address'>
#      |
#      |  JOB_TITLE = <FieldType.JOB_TITLE: 'job_title'>
#      |
#      |  JWT_TOKEN = <FieldType.JWT_TOKEN: 'jwt_token'>
#      |
#      |  LAST_NAME = <FieldType.LAST_NAME: 'last_name'>
#      |
#      |  LATITUDE = <FieldType.LATITUDE: 'latitude'>
#      |
#      |  LONGITUDE = <FieldType.LONGITUDE: 'longitude'>
#      |
#      |  MAC_ADDRESS = <FieldType.MAC_ADDRESS: 'mac_address'>
#      |
#      |  PARAGRAPH = <FieldType.PARAGRAPH: 'paragraph'>
#      |
#      |  PASSWORD = <FieldType.PASSWORD: 'password'>
#      |
#      |  PASSWORD_HASH = <FieldType.PASSWORD_HASH: 'password_hash'>
#      |
#      |  PERCENTAGE = <FieldType.PERCENTAGE: 'percentage'>
#      |
#      |  PHONE = <FieldType.PHONE: 'phone'>
#      |
#      |  SECRET_TOKEN = <FieldType.SECRET_TOKEN: 'secret_token'>
#      |
#      |  SENTENCE = <FieldType.SENTENCE: 'sentence'>
#      |
#      |  SLUG = <FieldType.SLUG: 'slug'>
#      |
#      |  STATE = <FieldType.STATE: 'state'>
#      |
#      |  STATUS = <FieldType.STATUS: 'status'>
#      |
#      |  TAG = <FieldType.TAG: 'tag'>
#      |
#      |  TIME = <FieldType.TIME: 'time'>
#      |
#      |  TIMESTAMP = <FieldType.TIMESTAMP: 'timestamp'>
#      |
#      |  TITLE = <FieldType.TITLE: 'title'>
#      |
#      |  URL = <FieldType.URL: 'url'>
#      |
#      |  USERNAME = <FieldType.USERNAME: 'username'>
#      |
#      |  USER_AGENT = <FieldType.USER_AGENT: 'user_agent'>
#      |
#      |  UUID = <FieldType.UUID: 'uuid'>
#      |
#      |  WEBHOOK_URL = <FieldType.WEBHOOK_URL: 'webhook_url'>
#      |
#      |  WORD = <FieldType.WORD: 'word'>
#      |
#      |  ZIP_CODE = <FieldType.ZIP_CODE: 'zip_code'>
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from enum.Enum:
#      |
#      |  name
#      |      The name of the Enum member.
#      |
#      |  value
#      |      The value of the Enum member.
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties inherited from enum.EnumMeta:
#      |
#      |  __members__
#      |      Returns a mapping of member name->value.
#      |
#      |      This mapping lists all enum members, including aliases. Note that this
#      |      is a read-only view of the internal mapping.
#
#     class GenerationResult(builtins.object)
#      |  GenerationResult(records: List[Dict], summary: List[fakesmith.result.FieldSummary] = <factory>, warnings: List[str] = <factory>, seed: Optional[int] = None) -> None
#      |
#      |  Returned by FakeSmith.generate() and all to_*() methods when
#      |  return_summary=True is passed (or always from generate_with_summary()).
#      |
#      |  Attributes:
#      |      records:   The generated fake records.
#      |      summary:   Per-field breakdown of what was detected and replaced.
#      |      warnings:  Human-readable warnings for sensitive fields found.
#      |      seed:      The seed used, if any (None = random).
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(self, other)
#      |
#      |  __init__(self, records: List[Dict], summary: List[fakesmith.result.FieldSummary] = <factory>, warnings: List[str] = <factory>, seed: Optional[int] = None) -> None
#      |
#      |  __repr__(self)
#      |
#      |  print_summary(self) -> None
#      |      Print a human-readable change report to stdout.
#      |
#      |  to_dict(self) -> dict
#      |      Machine-readable summary dict.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __annotations__ = {'records': typing.List[typing.Dict], 'seed': typing...
#      |
#      |  __dataclass_fields__ = {'records': Field(name='records',type=typing.Li...
#      |
#      |  __dataclass_params__ = _DataclassParams(init=True,repr=True,eq=True,or...
#      |
#      |  __hash__ = None
#      |
#      |  seed = None
#
#     class SanitizeResult(builtins.object)
#      |  SanitizeResult(original: str, sanitized: str, replacements: List[Dict], warnings: List[str]) -> None
#      |
#      |  SanitizeResult(original: str, sanitized: str, replacements: List[Dict], warnings: List[str])
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(self, other)
#      |
#      |  __init__(self, original: str, sanitized: str, replacements: List[Dict], warnings: List[str]) -> None
#      |
#      |  __repr__(self)
#      |
#      |  print_summary(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __annotations__ = {'original': <class 'str'>, 'replacements': typing.L...
#      |
#      |  __dataclass_fields__ = {'original': Field(name='original',type=<class ...
#      |
#      |  __dataclass_params__ = _DataclassParams(init=True,repr=True,eq=True,or...
#      |
#      |  __hash__ = None
#
#     class SchemaField(builtins.object)
#      |  SchemaField(name: str, field_type: fakesmith.schema.FieldType, nullable: bool = False, null_probability: float = 0.1, choices: Optional[list] = None, min_value: Optional[float] = None, max_value: Optional[float] = None, prefix: Optional[str] = None, generator: Optional[Callable] = None, locale: Optional[str] = None) -> None
#      |
#      |  Defines a single field in your data schema.
#      |
#      |  Examples:
#      |      SchemaField("user_id", FieldType.UUID)
#      |      SchemaField("status", FieldType.STATUS, choices=["active", "inactive"])
#      |      SchemaField("score", FieldType.INTEGER, min_value=0, max_value=100)
#      |      SchemaField("ref_code", FieldType.CUSTOM, generator=lambda: "REF-" + str(random.randint(1000,9999)))
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(self, other)
#      |
#      |  __init__(self, name: str, field_type: fakesmith.schema.FieldType, nullable: bool = False, null_probability: float = 0.1, choices: Optional[list] = None, min_value: Optional[float] = None, max_value: Optional[float] = None, prefix: Optional[str] = None, generator: Optional[Callable] = None, locale: Optional[str] = None) -> None
#      |
#      |  __post_init__(self)
#      |
#      |  __repr__(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __annotations__ = {'choices': typing.Optional[list], 'field_type': <en...
#      |
#      |  __dataclass_fields__ = {'choices': Field(name='choices',type=typing.Op...
#      |
#      |  __dataclass_params__ = _DataclassParams(init=True,repr=True,eq=True,or...
#      |
#      |  __hash__ = None
#      |
#      |  choices = None
#      |
#      |  generator = None
#      |
#      |  locale = None
#      |
#      |  max_value = None
#      |
#      |  min_value = None
#      |
#      |  null_probability = 0.1
#      |
#      |  nullable = False
#      |
#      |  prefix = None
#
# FUNCTIONS
#     infer_schema(source: Union[str, dict, list], source_type: str = 'auto') -> list
#         Infer a list of SchemaFields from sample data.
#
#         Args:
#             source:      A JSON string, CSV string, Python dict, or list of dicts.
#             source_type: "json" | "csv" | "dict" | "auto" (default)
#
#         Returns:
#             List of SchemaField objects ready to pass into FakeSmith.
#
#     sanitize_text(text: str, seed: Optional[int] = None) -> fakesmith.sanitizer.SanitizeResult
#         Scan a raw string for secrets and PII, replace each match with a
#         realistic fake value, and return the cleaned string + change log.
#
#         Args:
#             text: Any string — log line, config block, .env file, plain text.
#             seed: Optional random seed for deterministic output.
#
#         Returns:
#             SanitizeResult with .sanitized, .replacements, .warnings
#
# DATA
#     __all__ = ['FakeSmith', 'SchemaField', 'FieldType', 'infer_schema', 's...
#
# FILE
#     /Users/jeff/Library/Python/3.9/lib/python/site-packages/fakesmith/__init__.py

# %%
3dac7771-9b22-44fe-b790-5e681a20dc3e

# %%
from fakesmith import FakeSmith

# Paste a real (or representative) sample — FakeSmith reads its shape
sample = '''[{
    "api_key": "3dac7771-9b22-44fe-b790-5e681a20dc3e"
}]'''

smith = FakeSmith.from_sample(sample)
smith.describe()          # see what was detected
print(smith.to_json(1))   # 5 fake records, same shape
# print(smith.to_json(5))   # 5 fake records, same shape
# Out:
#   Field                    Type                   Sensitive    Nullable
#   ──────────────────────────────────────────────────────────────────
#   api_key                  api_key                *** YES ***  no
#
#   [WARNING] Sensitive field 'api_key' (api_key) detected — real values replaced with fakes.
#
# [
#   {
#     "api_key": "sk-gclcqdsvtehcbgjti3xf56ejklkizvdq"
#   }
# ]
